# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('NER_stats.txt') as f:
    data = [json.loads(line) for line in f.readlines()]

# %%
df = pd.DataFrame(data)

# %%
plot = df.plot(x='model_name', y='mean_score')
ylim = plt.ylim(0.8,0.92)

# %%
df.model_name
# Out:
# 0              bert-base-uncased
# 1       model-trained-0-3531-4GB
# 2     model-trained-18-67089-4GB
# 3    model-trained-36-130647-4GB
# 4     model-trained-0-10596-12GB
# 5     model-trained-3-42384-12GB
# 6     model-trained-5-63576-12GB
# Name: model_name, dtype: object
